# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
import lightgbm as lgb
from IPython.display import display
from sklearn.model_selection import train_test_split
import eli5
from eli5.sklearn import PermutationImportance

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 18
plt.rcParams['patch.edgecolor'] = 'k'

# %%
pd.options.display.max_columns = 150

# Read in data
train = pd.read_csv('data/train_processed.csv')
train_selected = pd.read_csv('data/train_selected.csv')

# %%
scorer = make_scorer(f1_score, greater_is_better=True, average = 'macro')

# %%
X_train = train.drop(columns=["Target",'idhogar'])
X_selected = train_selected.drop(columns=["Target",'idhogar'])
y_train = train['Target']

# %%
def macro_f1_score(labels, predictions):
    # Reshape the predictions as needed
    predictions = predictions.reshape(len(np.unique(labels)), -1 ).argmax(axis = 0)
    
    metric_value = f1_score(labels, predictions, average = 'macro')
    
    # Return is name, value, is_higher_better
    return 'macro_f1', metric_value, True

# %%
best_params = {'boosting_type': 'dart',
 'colsample_bytree': 0.6096416248120604,
 'learning_rate': 0.19779582059725404,
 'limit_max_depth': True,
 'max_depth': 24,
 'min_child_samples': 35,
 'num_leaves': 42,
 'reg_alpha': 0.41161294322049163,
 'reg_lambda': 0.6745579773545685,
 'subsample_for_bin': 50000,
 'drop_rate': 0.48718668776524016,
 'subsample': 0.5220648456225067,
 'subsample_freq': 9,
 'n_estimators': 120}

# %%
model = lgb.LGBMClassifier(**best_params, class_weight = 'balanced',
                               n_jobs=-1, metric = 'None')

# %%
model.fit(X_selected, y_train, )
# Out:
# LGBMClassifier(boosting_type='dart', class_weight='balanced',
#         colsample_bytree=0.6096416248120604, drop_rate=0.48718668776524016,
#         importance_type='split', learning_rate=0.19779582059725404,
#         limit_max_depth=True, max_depth=24, metric='None',
#         min_child_samples=35, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=120, n_jobs=-1, num_leaves=42, objective=None,
#         random_state=None, reg_alpha=0.41161294322049163,
#         reg_lambda=0.6745579773545685, silent=True,
#         subsample=0.5220648456225067, subsample_for_bin=50000,
#         subsample_freq=9)

# %% [markdown]
# -----------------------------

# %% [markdown]
# ## Confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Oranges):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    Source: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize = (10, 10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, size = 24)
    plt.colorbar(aspect=4)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, size = 14)
    plt.yticks(tick_marks, classes, size = 14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    
    # Labeling the plot
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), fontsize = 20,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
    plt.grid(None)
    plt.tight_layout()
    plt.ylabel('True label', size = 18)
    plt.xlabel('Predicted label', size = 18)

# %%
pred = model.predict(X_selected)
cm = confusion_matrix(y_train, pred)

plot_confusion_matrix(cm, classes = ['Extreme', 'Moderate', 'Vulnerable', 'Non-Vulnerable'],
                      title = 'Poverty Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 210    2    8    2]
#  [  14  394   12   22]
#  [   6   20  316   13]
#  [  64  131  147 1612]]

# %% [markdown]
# # Feature importance

# %% [markdown]
# ## by scikit-learn

# %%
df = pd.DataFrame(data={"features": X_selected.columns.values, "importance": model.feature_importances_})
df.sort_values(
    by="importance", ascending=False).head(10)
# Out:
#             features  importance
# 53           age-sum         627
# 61  escolari/age-sum         566
# 54           age-std         530
# 49      escolari-std         515
# 59  escolari/age-min         487
# 51           age-min         478
# 52           age-max         469
# 10          meaneduc         444
# 60  escolari/age-max         443
# 64      inst/age-max         413

# %% [markdown]
# ## by eli5

# %%
p_train, p_test, l_train, l_test = train_test_split(X_selected, y_train, random_state=42)

# %%
model.fit(p_train, l_train)
perm = PermutationImportance(model).fit(p_test, l_test)

# %%
eli5.show_weights(perm, feature_names=X_selected.columns.values)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0105
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 inst-std
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0073
#
#                     &plusmn; 0.0178
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age-max
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0051
#
#                     &plusmn; 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age-std
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0046
#
#                     &plusmn; 0.0115
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 edjefa
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0040
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 edjefe
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0035
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 age-min
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.10%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0030
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bedrooms
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0047
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 meaneduc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0022
#
#                     &plusmn; 0.0027
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 floor
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0016
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tamviv
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 roof
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0011
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 instlevel2-std
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0008
#
#                     &plusmn; 0.0050
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 paredblolad
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0003
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 eviv3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0085
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lugar1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0088
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 rooms-per-capita
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.34%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0003
#
#                     &plusmn; 0.0067
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 v2a1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0005
#
#                     &plusmn; 0.0022
#
#             </td>
#             <td style

# %%
eli5.explain_weights_lightgbm(model, feature_names=X_selected.columns.values)
# Out:
# Explanation(estimator="LGBMClassifier(boosting_type='dart', class_weight='balanced',\n        colsample_bytree=0.6096416248120604, drop_rate=0.48718668776524016,\n        importance_type='split', learning_rate=0.19779582059725404,\n        limit_max_depth=True, max_depth=24, metric='None',\n        min_child_samples=35, min_child_weight=0.001, min_split_gain=0.0,\n        n_estimators=120, n_jobs=-1, num_leaves=42, objective=None,\n        random_state=None, reg_alpha=0.41161294322049163,\n        reg_lambda=0.6745579773545685, silent=True,\n        subsample=0.5220648456225067, subsample_for_bin=50000,\n        subsample_freq=9)", description='\nLightGBM feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='escolari-max', weight=0.0575931806146541, std=None, value=None), FeatureWeight(feature='age-sum', weight=0.0495876201905896, std=None, value=None), FeatureWeight(feature='meaneduc', weight=0.03927235828353192, std=None, value=None), FeatureWeight(feature='escolari/age-sum', weight=0.03911978224748185, std=None, value=None), FeatureWeight(feature='age-min', weight=0.037994352786146955, std=None, value=None), FeatureWeight(feature='age-max', weight=0.03678096473121454, std=None, value=None), FeatureWeight(feature='escolari/age-max', weight=0.03129016273180479, std=None, value=None), FeatureWeight(feature='age-std', weight=0.030694968087111644, std=None, value=None), FeatureWeight(feature='escolari/age-min', weight=0.03031200166718728, std=None, value=None), FeatureWeight(feature='dependency', weight=0.03014258701768177, std=None, value=None), FeatureWeight(feature='phones-per-capita', weight=0.029837213059895524, std=None, value=None), FeatureWeight(feature='escolari-std', weight=0.029764185445648936, std=None, value=None), FeatureWeight(feature='escolari-sum', weight=0.028738698178768143, std=None, value=None), FeatureWeight(feature='escolari/age-range_', weight=0.027680168520215095, std=None, value=None), FeatureWeight(feature='rooms-per-capita', weight=0.026664264331091023, std=None, value=None), FeatureWeight(feature='edjefe', weight=0.02558977796402679, std=None, value=None), FeatureWeight(feature='inst/age-max', weight=0.025081151682384745, std=None, value=None), FeatureWeight(feature='inst/age-std', weight=0.02300055963441741, std=None, value=None), FeatureWeight(feature='escolari/age-std', weight=0.022044934998303234, std=None, value=None), FeatureWeight(feature='age-range_', weight=0.021981329118342417, std=None, value=None)], remaining=48), decision_tree=None, highlight_spaces=None, transition_features=None)

# %% [markdown]
# ## Investigation of the confusion matrix

# %%
p_train, p_test, l_train, l_test = train_test_split(X_selected, y_train, random_state=42)
model.fit(p_train, l_train)
pred = model.predict(p_test)
cm = confusion_matrix(l_test, pred)

plot_confusion_matrix(cm, classes = ['Extreme', 'Moderate', 'Vulnerable', 'Non-Vulnerable'],
                      title = 'Poverty Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[ 27  12  12   7]
#  [ 21  46  25  24]
#  [ 12  23  26  29]
#  [ 20  48  65 347]]

# %%
import shap
from IPython.display import display, HTML

shap.initjs()

def get_indexes(test_results, true_label, pred_label):
    return test_results[(test_results['Target']==true_label) & (test_results['Predicted']==pred_label)].index

def get_cofused_entries(df, test_results, true_label, pred_label):
    return df.loc[get_indexes(test_results, true_label, pred_label)]

def plot_influence_on_pred(df, shap_values, expected_value, index):
    display(HTML("<h1>What influenced prediction for {}th sample</h1>".format(index+1)))
    display(HTML("<h2>Prediction of class 4 (Non-vulnerable) probability"))
    display(shap.force_plot(expected_value[3], shap_values[3][index], df.iloc[index,:]))
#     display(HTML("<h2>Prediction of class 3 (Vulnerable) probability"))
#     display(shap.force_plot(expected_value[2], shap_values[2][index], df.iloc[index,:]))
#     display(HTML("<h2>Prediction of class 2 (Moderate vulnerability) probability"))
#     display(shap.force_plot(expected_value[1], shap_values[1][index], df.iloc[index,:]))
    display(HTML("<h2>Prediction of class 1 (Extreme vulnerability) probability"))
    display(shap.force_plot(expected_value[0], shap_values[0][index], df.iloc[index,:]))
    
def sample_and_explain(df, number_of_samples, random_state, shap_values, expected_value):
    for sample_id in df.sample(number_of_samples, random_state=random_state).index.values:
        index = df.index.get_loc(sample_id)
        plot_influence_on_pred(df, shap_values, expected_value, index)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=189)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";var r=n(11),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var i=Object.getOwnPropertySymbols,o=Object.prototype.hasOwnProperty,a=Object.prototype.propertyIsEnumerable;t.exports=function(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;if("0123456789"!==Object.getOwnPropertyNames(e).map(function(t){return e[t]}).join(""))return!1;var r={};return"abcdefghijklmnopqrst".split("").forEach(function(t){r[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},r)).join("")}catch(t){return!1}}()?Object.assign:function(t,e){for(var n,u,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)o.call(n,l)&&(c[l]=n[l]);if(i){u=i(n);for(var f=0;f<u.length;f++)a.call(n,u[f])&&(c[u[f]]=n[u[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode&&f("33"),t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent||f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(1),p=n(21),h=n(161),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o,a=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return a;do{a.push(o=new Date(+n)),e(n,i),t(n)}while(o<n&&n<r);return a},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)if(r<0)for(;++r<=0;)for(;e(t,-1),!n(t););else for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t==0}:function(e){return u.count(0,e)%t==0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";Object.defineProperty(e,"__esModule",{value:!0});var r=n(101);n.d(e,"bisect",function(){return r.a}),n.d(e,"bisectRight",function(){return r.b}),n.d(e,"bisectLeft",function(){return r.c});var i=n(19);n.d(e,"ascending",function(){return i.a});var o=n(102);n.d(e,"bisector",function(){return o.a});var a=n(193);n.d(e,"cross",function(){return a.a});var u=n(194);n.d(e,"descending",function(){return u.a});var c=n(103);n.d(e,"deviation",function(){return c.a});var s=n(104);n.d(e,"extent",function(){return s.a});var l=n(195);n.d(e,"histogram",function(){return l.a});var f= ...

# %%
test_results = pd.DataFrame(data=l_test)
test_results['Predicted'] = pred

nonvul_as_extreme = get_cofused_entries(p_test, test_results, 4, 1)
extreme_as_nonvul = get_cofused_entries(p_test, test_results, 1, 4)

# %%
explainer = shap.TreeExplainer(model)

shap_values = explainer.shap_values(X_selected)
shap.summary_plot(shap_values, nonvul_as_extreme, class_names=['Extreme vulnerability', 'Moderate vulnerability', 'Vulnerable', 'Non-vulnerable'])
expected_value = explainer.expected_value
features = ['escolari-max', 'age-sum', 'meaneduc', 'escolari/age-sum', 'age-min', 'age-max', 'escolari/age-max', 'age-std', 'escolari/age-min', 'dependency', 'phones-per-capita']

for name in features:
    shap.dependence_plot(name, shap_values[0], X_selected)

# for name in features:
#     shap.dependence_plot(name, shap_values[0][nonvul_as_extreme.index.values], X_selected.loc[nonvul_as_extreme.index])

# %%
shap_values = explainer.shap_values(nonvul_as_extreme)
shap.summary_plot(shap_values, nonvul_as_extreme, class_names=['Extreme vulnerability', 'Moderate vulnerability', 'Vulnerable', 'Non-vulnerable'])
expected_value = explainer.expected_value
sample_and_explain(nonvul_as_extreme, 4, 42, shap_values, expected_value)
# Out:
# <h1>What influenced prediction for 1th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='i28GJS8VYVZFYD1V7F6AH'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": -0.9722533397129439, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.046898226125538164, "value": 1.0}, "1": {"effect": 0.04124274974741594, "value": 1.0}, "2": {"effect": 0.018695722393546152, "value": 1.0}, "3": {"effect": 0.020158553088083103, "value": 0.0}, "4": {"effect": -0.16073194363209845, "value": 0.0}, "5": {"effect": -0.07457527911640664, "value": 0.0}, "6": {"effect": -0.0812086643870588, "value": 0.0}, "7": {"effect": 0.19130205418905566, "value": 0.0}, "8": {"effect": -0.0069191744568910555, "value": 0.0}, "9": {"effect": -0.013741975213757026, "value": 0.0}, "10": {"effect": -0.166136243449583, "value": 0.0}, "11": {"effect": 0.02920441917407441, "value": 0.13793103448275862}, "12": {"effect": 0.063412151436438, "value": 0.20000000000000004}, "13": {"effect": 0.0067742176737535355, "value": 0.125}, "14": {"effect": -0.00021664084137602656, "value": 0.125}, "15": {"effect": 0.053487865423842935, "value": 0.0}, "16": {"effect": 0.000547320467015857, "value": 0.0}, "17": {"effect": -0.00017453898912694486, "value": 0.0}, "18": {"effect": 0.005118082797125792, "value": 0.0}, "19": {"effect": 0.030868002480238545, "value": 0.0}, "20": {"effect": -0.06023967031794856, "value": 0.1111111111111111}, "21": {"effect": -0.020494924325396412, "value": 0.0}, "22": {"effect": -0.0219241360449791, "value": 0.1}, "23": {"effect": -0.0031292181629903105, "value": 0.5}, "24": {"effect": 0.020001198070533743, "value": 1.0}, "25": {"effect": -0.008487990773882383, "value": 0.0}, "26": {"effect": -0.18200749794423043, "value": 0.5}, "27": {"effect": 0.026064575565362257, "value": 0.0}, "28": {"effect": -0.06411772614688639, "value": 0.25}, "29": {"effect": 0.19451916615014853, "value": 0.3333333333333333}, "30": {"effect": 0.06557594063874875, "value": 0.3207547169811321}, "31": {"effect": -0.060350564366886884, "value": 0.0}, "32": {"effect": -0.0007628938672865095, "value": 0.0}, "33": {"effect": -0.0027075107719269458, "value": 0.8164965809277259}, "34": {"effect": 0.004704680041647995, "value": 0.0}, "35": {"effect": -0.0198159019700192, "value": 0.7302967433402213}, "36": {"effect": -0.0026853606922100756, "value": 0.7071067811865475}, "37": {"effect": 0.00046743912326238673, "value": 0.0}, "38": {"effect": 0.0031366992904583424, "value": 0.2}, "39": {"effect": 0.004557712452222443, "value": 0.0}, "40": {"effect": -0.007017537104239241, "value": 0.0}, "41": {"effect": -0.035659897589697995, "value": 0.0}, "42": {"effect": -0.026579181435183726, "value": 0.0}, "43": {"effect": 0.02194852994516872, "value": 0.0}, "44": {"effect": -0.03644915936244516, "value": 0.0}, "45": {"effect": -0.007509500142583561, "value": 0.0}, "46": {"effect": -0.12003050250272174, "value": 0.0}, "47": {"effect": -0.36937094371116885, "value": 0.0}, "48": {"effect": -0.1277869836496255, "value": 0.0}, "49": {"effect": -0.040994115476 ...
#     document.getElementById('i28GJS8VYVZFYD1V7F6AH')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='iGQKJ9UOO1CVU7J0MFYQ5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": 0.40258769665461647, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.02192804089689139, "value": 1.0}, "1": {"effect": -0.037940590709611706, "value": 1.0}, "2": {"effect": -0.04751940013910846, "value": 1.0}, "3": {"effect": 0.0008603458212081721, "value": 0.0}, "4": {"effect": 0.11290042154762796, "value": 0.0}, "5": {"effect": 0.06412995077142385, "value": 0.0}, "6": {"effect": 0.05307561876420423, "value": 0.0}, "7": {"effect": 0.14414930834044198, "value": 0.0}, "8": {"effect": 0.07018299735407099, "value": 0.0}, "9": {"effect": 0.05992645133860044, "value": 0.0}, "10": {"effect": 0.18006293472073917, "value": 0.0}, "11": {"effect": -0.01256595211536604, "value": 0.13793103448275862}, "12": {"effect": -0.015081168986856087, "value": 0.20000000000000004}, "13": {"effect": 0.12471562027342796, "value": 0.125}, "14": {"effect": 0.03211719921932047, "value": 0.125}, "15": {"effect": 0.030313705998417022, "value": 0.0}, "16": {"effect": -0.0032903412149680577, "value": 0.0}, "17": {"effect": 5.05731462533774e-05, "value": 0.0}, "18": {"effect": 0.006520983778931847, "value": 0.0}, "19": {"effect": -0.0007885813491696377, "value": 0.0}, "20": {"effect": 0.008313391293209718, "value": 0.1111111111111111}, "21": {"effect": 0.08377845509126755, "value": 0.0}, "22": {"effect": 0.033649849913074806, "value": 0.1}, "23": {"effect": 0.061487527556897556, "value": 0.5}, "24": {"effect": -0.010990955851982252, "value": 1.0}, "25": {"effect": 0.012477294323208583, "value": 0.0}, "26": {"effect": 0.04321118773635927, "value": 0.5}, "27": {"effect": -0.018448944826297168, "value": 0.0}, "28": {"effect": 0.00781751173519433, "value": 0.25}, "29": {"effect": -0.019778907014877698, "value": 0.3333333333333333}, "30": {"effect": -0.006250268893011602, "value": 0.3207547169811321}, "31": {"effect": 0.0289129427222823, "value": 0.0}, "32": {"effect": 0.003816212235546238, "value": 0.0}, "33": {"effect": 0.03199127217113694, "value": 0.8164965809277259}, "34": {"effect": 0.0001576424223564423, "value": 0.0}, "35": {"effect": 0.00027870216660934484, "value": 0.7302967433402213}, "36": {"effect": 0.0015921784513527248, "value": 0.7071067811865475}, "37": {"effect": -0.002923949462385965, "value": 0.0}, "38": {"effect": 0.06414570964613618, "value": 0.2}, "39": {"effect": -0.006889241494202331, "value": 0.0}, "40": {"effect": -0.020189351957195307, "value": 0.0}, "41": {"effect": 0.019453627269583915, "value": 0.0}, "42": {"effect": 0.009698721356005791, "value": 0.0}, "43": {"effect": 0.0021973150391253167, "value": 0.0}, "44": {"effect": 0.001236848851040913, "value": 0.0}, "45": {"effect": -0.0020273067791598547, "value": 0.0}, "46": {"effect": 0.04164358120443925, "value": 0.0}, "47": {"effect": 0.009890138438661593, "value": 0.0}, "48": {"effect": 0.20272217585017377, "value": 0.0}, "49": {"effect": 0.0647224370493391, "value ...
#     document.getElementById('iGQKJ9UOO1CVU7J0MFYQ5')
#   );
# </script>
# <h1>What influenced prediction for 18th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='iSJEHCT6C7G3C97EKDIME'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": -0.2473571295249704, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.03443024925895887, "value": 1.0}, "1": {"effect": -0.10194737772965913, "value": 0.0}, "2": {"effect": -0.03742933871264487, "value": 0.0}, "3": {"effect": 0.005436679781273131, "value": 0.0}, "4": {"effect": -0.16798480562763696, "value": 0.0}, "5": {"effect": 0.05397817795131694, "value": 1.0}, "6": {"effect": -0.06903369738742154, "value": 0.0}, "7": {"effect": 0.28945690435114746, "value": 0.0}, "8": {"effect": 0.041825578899384215, "value": 0.3333333333333333}, "9": {"effect": -0.01185176735179653, "value": 0.0}, "10": {"effect": -0.08439785745453927, "value": 0.1891891891891892}, "11": {"effect": 0.025404593111346137, "value": 0.05172413793103448}, "12": {"effect": -0.0641982692564146, "value": 0.30000000000000004}, "13": {"effect": 0.006175726369991729, "value": 0.125}, "14": {"effect": -0.0016001350157511351, "value": 0.125}, "15": {"effect": 0.033205649275263274, "value": 0.0}, "16": {"effect": 0.0008403927479139401, "value": 0.0}, "17": {"effect": -0.0009856345186769944, "value": 0.0}, "18": {"effect": 0.00255258643394636, "value": 0.0}, "19": {"effect": 0.02166750730790598, "value": 0.0}, "20": {"effect": -0.06509757818560478, "value": 0.1111111111111111}, "21": {"effect": -0.0008849674679779482, "value": 0.14285714285714285}, "22": {"effect": -0.023072934093481542, "value": 0.1}, "23": {"effect": -0.0035821783244462924, "value": 0.5}, "24": {"effect": 0.014155095763646385, "value": 1.0}, "25": {"effect": -0.014947277127896943, "value": 0.5}, "26": {"effect": -0.08460459018087983, "value": 0.6666666666666666}, "27": {"effect": -0.014590191933975798, "value": 0.25}, "28": {"effect": -0.04196272046800647, "value": 0.25}, "29": {"effect": 0.22294886124256524, "value": 0.3333333333333333}, "30": {"effect": 0.02936257649338949, "value": 0.43396226415094336}, "31": {"effect": -0.05253959751690781, "value": 0.0}, "32": {"effect": 0.005939535717576447, "value": 0.0}, "33": {"effect": -0.0016370870802389502, "value": 0.8164965809277259}, "34": {"effect": 0.005039012023994751, "value": 0.0}, "35": {"effect": -0.039168429165975134, "value": 0.7302967433402213}, "36": {"effect": 0.008179329128568303, "value": 0.7071067811865475}, "37": {"effect": -0.0031806371362153533, "value": 0.0}, "38": {"effect": 0.011257860208209501, "value": 0.0}, "39": {"effect": 0.004567920340685597, "value": 0.0}, "40": {"effect": 0.005092638146435841, "value": 0.0}, "41": {"effect": -0.026854049764953872, "value": 0.0}, "42": {"effect": -0.010549297623450856, "value": 0.0}, "43": {"effect": 0.027449716607150863, "value": 0.0}, "44": {"effect": -0.03157309755717003, "value": 0.0}, "45": {"effect": -0.008266121376147515, "value": 0.0}, "46": {"effect": 0.13739021007989524, "value": 0.3333333333333333}, "47": {"effect": -0.25756531770086977, "value": 0.33333333333333 ...
#     document.getElementById('iSJEHCT6C7G3C97EKDIME')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='iCFRBQV8E7E2P3Z2I77VS'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": 0.19817862592761593, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.019656525144189998, "value": 1.0}, "1": {"effect": 0.15287012168566025, "value": 0.0}, "2": {"effect": 0.11319021282637819, "value": 0.0}, "3": {"effect": 0.003787284645961257, "value": 0.0}, "4": {"effect": 0.09852044562849378, "value": 0.0}, "5": {"effect": -0.04364237793237394, "value": 1.0}, "6": {"effect": 0.05428543505496044, "value": 0.0}, "7": {"effect": 0.12657930271440296, "value": 0.0}, "8": {"effect": -0.045253488723657934, "value": 0.3333333333333333}, "9": {"effect": 0.030230092989954584, "value": 0.0}, "10": {"effect": -0.011118377180221213, "value": 0.1891891891891892}, "11": {"effect": -0.0339124070953898, "value": 0.05172413793103448}, "12": {"effect": 0.01834499275225209, "value": 0.30000000000000004}, "13": {"effect": 0.10514226726951441, "value": 0.125}, "14": {"effect": 0.028614183165186033, "value": 0.125}, "15": {"effect": 0.0042189561212411615, "value": 0.0}, "16": {"effect": -0.0036387371943725293, "value": 0.0}, "17": {"effect": 0.020320977764841368, "value": 0.0}, "18": {"effect": 0.013857286646690153, "value": 0.0}, "19": {"effect": 0.0007259694316038433, "value": 0.0}, "20": {"effect": 0.031533721862098164, "value": 0.1111111111111111}, "21": {"effect": 0.00891631697731963, "value": 0.14285714285714285}, "22": {"effect": 0.06958676748899015, "value": 0.1}, "23": {"effect": 0.043784759582272945, "value": 0.5}, "24": {"effect": -0.017369175825528844, "value": 1.0}, "25": {"effect": 0.0174330334750539, "value": 0.5}, "26": {"effect": 0.04607635456871744, "value": 0.6666666666666666}, "27": {"effect": 0.017577438925928012, "value": 0.25}, "28": {"effect": 0.01596212182838356, "value": 0.25}, "29": {"effect": -0.07533264616380173, "value": 0.3333333333333333}, "30": {"effect": -0.010270658985733675, "value": 0.43396226415094336}, "31": {"effect": 0.04684703233720437, "value": 0.0}, "32": {"effect": -0.008966579788426292, "value": 0.0}, "33": {"effect": 0.023241195726255492, "value": 0.8164965809277259}, "34": {"effect": -0.00014968623281606678, "value": 0.0}, "35": {"effect": 0.00035625251414405246, "value": 0.7302967433402213}, "36": {"effect": -0.002752737380771188, "value": 0.7071067811865475}, "37": {"effect": -0.0041964321303777615, "value": 0.0}, "38": {"effect": -0.005624148223866147, "value": 0.0}, "39": {"effect": 0.007324175662937911, "value": 0.0}, "40": {"effect": 0.007385497563580708, "value": 0.0}, "41": {"effect": 0.0023503878146887616, "value": 0.0}, "42": {"effect": 0.003600912632762172, "value": 0.0}, "43": {"effect": 0.0011300804342710786, "value": 0.0}, "44": {"effect": 0.001236848851040913, "value": 0.0}, "45": {"effect": -0.0011685720312734557, "value": 0.0}, "46": {"effect": 0.0007597934263260213, "value": 0.3333333333333333}, "47": {"effect": -0.01448229761137393, "value": 0.3333333333333333} ...
#     document.getElementById('iCFRBQV8E7E2P3Z2I77VS')
#   );
# </script>
# <h1>What influenced prediction for 16th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='iHBQDWJ4PP6KHQAW223HR'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": -1.5561004817491957, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.029882377256852256, "value": 1.0}, "1": {"effect": 0.03533348867978297, "value": 1.0}, "2": {"effect": 0.008306102647792262, "value": 1.0}, "3": {"effect": -0.01354688488046361, "value": 1.0}, "4": {"effect": -0.07885677426291123, "value": 0.0}, "5": {"effect": 0.011793557103231642, "value": 1.0}, "6": {"effect": -0.09802090263740756, "value": 0.0}, "7": {"effect": -0.22240635182965715, "value": 0.25}, "8": {"effect": -0.06931439396655058, "value": 0.0}, "9": {"effect": -0.010151967196141112, "value": 0.2380952380952381}, "10": {"effect": -0.10734016518928628, "value": 0.14864864864864866}, "11": {"effect": 0.02355437145493089, "value": 0.09482758620689656}, "12": {"effect": -0.008009419705631555, "value": 0.4}, "13": {"effect": -0.016961227884765766, "value": 0.125}, "14": {"effect": -0.003394895690652281, "value": 0.125}, "15": {"effect": -0.011005621007177693, "value": 0.25}, "16": {"effect": -0.003984350723671044, "value": 0.14285714285714285}, "17": {"effect": 0.012039886577202855, "value": 0.1}, "18": {"effect": 0.0016204957544078296, "value": 0.14285714285714285}, "19": {"effect": -0.0054085833110956525, "value": 0.1111111111111111}, "20": {"effect": 0.00880907716237229, "value": 0.2222222222222222}, "21": {"effect": 0.0009462516340667702, "value": 0.42857142857142855}, "22": {"effect": 0.00336200085320637, "value": 0.2}, "23": {"effect": -0.0031753256868520233, "value": 0.5}, "24": {"effect": -0.0169048144545535, "value": 0.5}, "25": {"effect": -0.003814487555568971, "value": 0.5}, "26": {"effect": -0.19988911938514597, "value": 0.5}, "27": {"effect": 0.03832759823783851, "value": 0.0}, "28": {"effect": 0.12506409110417774, "value": 0.5}, "29": {"effect": -0.09182374828083535, "value": 0.2222222222222222}, "30": {"effect": 0.02977753300103541, "value": 0.16981132075471694}, "31": {"effect": -0.07151660481743433, "value": 0.0}, "32": {"effect": 0.012272436995402102, "value": 0.25}, "33": {"effect": 0.0028093649273412107, "value": 0.8164965809277259}, "34": {"effect": -0.006797512890363398, "value": 0.1}, "35": {"effect": -0.009508308305280586, "value": 0.8164965809277259}, "36": {"effect": 0.004421596272439149, "value": 0.0}, "37": {"effect": 0.0014971421548683036, "value": 0.1}, "38": {"effect": -0.0009093764924308618, "value": 0.2}, "39": {"effect": -0.0027541004497381497, "value": 0.2}, "40": {"effect": 0.003441480522189088, "value": 0.8164965809277259}, "41": {"effect": 0.01337767759756048, "value": 0.14285714285714285}, "42": {"effect": 0.05976617355501002, "value": 0.8164965809277259}, "43": {"effect": 0.013277872607913235, "value": 0.0}, "44": {"effect": -0.038105193829719275, "value": 0.0}, "45": {"effect": -0.012314683549801097, "value": 0.0}, "46": {"effect": -0.12681993802815783, "value": 0.0}, "47": {"effect": -0.28304868 ...
#     document.getElementById('iHBQDWJ4PP6KHQAW223HR')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='i7WSVMTE8TRS0JKAYD1K8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": -0.1053196003739314, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.019968574204038646, "value": 1.0}, "1": {"effect": -0.02778790739915161, "value": 1.0}, "2": {"effect": -0.004001820936810368, "value": 1.0}, "3": {"effect": -0.0003957953745862828, "value": 1.0}, "4": {"effect": 0.023328865745819147, "value": 0.0}, "5": {"effect": -0.02809849054504777, "value": 1.0}, "6": {"effect": 0.06048069428586154, "value": 0.0}, "7": {"effect": 0.07357223973586481, "value": 0.25}, "8": {"effect": 0.19992274432670448, "value": 0.0}, "9": {"effect": 0.007742437486127796, "value": 0.2380952380952381}, "10": {"effect": -0.010991858415999168, "value": 0.14864864864864866}, "11": {"effect": -0.029598126556433093, "value": 0.09482758620689656}, "12": {"effect": 0.021195872104787534, "value": 0.4}, "13": {"effect": 0.06684597849384705, "value": 0.125}, "14": {"effect": 0.008033298978461664, "value": 0.125}, "15": {"effect": -0.008890757696603496, "value": 0.25}, "16": {"effect": 0.0014554669005287675, "value": 0.14285714285714285}, "17": {"effect": -0.017023396484720683, "value": 0.1}, "18": {"effect": 0.011832817689114008, "value": 0.14285714285714285}, "19": {"effect": 0.0024641886176597692, "value": 0.1111111111111111}, "20": {"effect": -0.001933910178309026, "value": 0.2222222222222222}, "21": {"effect": -0.10322687454488573, "value": 0.42857142857142855}, "22": {"effect": 0.010639917075605715, "value": 0.2}, "23": {"effect": 0.018504445116344678, "value": 0.5}, "24": {"effect": -0.01725761906416444, "value": 0.5}, "25": {"effect": 0.041545609770523025, "value": 0.5}, "26": {"effect": 0.08939277924022221, "value": 0.5}, "27": {"effect": -0.001828567098668122, "value": 0.0}, "28": {"effect": -0.022088870254348317, "value": 0.5}, "29": {"effect": 0.026961585210925686, "value": 0.2222222222222222}, "30": {"effect": 0.07072850768535259, "value": 0.16981132075471694}, "31": {"effect": 0.05872514971169524, "value": 0.0}, "32": {"effect": 0.0028086019642750834, "value": 0.25}, "33": {"effect": 0.01154278627388665, "value": 0.8164965809277259}, "34": {"effect": 0.011493487540847596, "value": 0.1}, "35": {"effect": 0.02920170329647023, "value": 0.8164965809277259}, "36": {"effect": -0.010103004850536848, "value": 0.0}, "37": {"effect": -0.019613338082314885, "value": 0.1}, "38": {"effect": 0.010102625177996, "value": 0.2}, "39": {"effect": -0.02397706999096972, "value": 0.2}, "40": {"effect": 0.0882333179769698, "value": 0.8164965809277259}, "41": {"effect": -0.030519181239926193, "value": 0.14285714285714285}, "42": {"effect": 0.020519622098634064, "value": 0.8164965809277259}, "43": {"effect": 0.017411681426472307, "value": 0.0}, "44": {"effect": 0.001236848851040913, "value": 0.0}, "45": {"effect": -0.0012834576298846418, "value": 0.0}, "46": {"effect": -0.016723496546512936, "value": 0.0}, "47": {"effect": -0.0332080168663364 ...
#     document.getElementById('i7WSVMTE8TRS0JKAYD1K8')
#   );
# </script>
# <h1>What influenced prediction for 2th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='i45R1XBH1Q1BMNHZCZ42A'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": -1.508772647701685, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.04277697027841112, "value": 0.0}, "1": {"effect": -0.06469825823952471, "value": 0.0}, "2": {"effect": -0.0526175103224291, "value": 0.0}, "3": {"effect": -0.010048949537787875, "value": 1.0}, "4": {"effect": -0.13361254603900735, "value": 0.0}, "5": {"effect": -0.06411860720316163, "value": 0.0}, "6": {"effect": -0.07154688629364701, "value": 0.0}, "7": {"effect": 0.15581042858453423, "value": 0.0}, "8": {"effect": 0.012362677384602611, "value": 0.2857142857142857}, "9": {"effect": -0.017075857668093452, "value": 0.0}, "10": {"effect": -0.09964821025473876, "value": 0.16216216216216214}, "11": {"effect": 0.02722634808419802, "value": 0.13793103448275862}, "12": {"effect": -0.03653222407964259, "value": 0.30000000000000004}, "13": {"effect": -0.0216097934285647, "value": 0.125}, "14": {"effect": -0.0013316352207007017, "value": 0.125}, "15": {"effect": -0.00856685432429488, "value": 0.125}, "16": {"effect": 0.0009088612378552792, "value": 0.0}, "17": {"effect": 0.0022877014947124998, "value": 0.1}, "18": {"effect": 0.0024956787675293078, "value": 0.07142857142857142}, "19": {"effect": 0.021211131080347743, "value": 0.0}, "20": {"effect": 0.003142722902577008, "value": 0.2222222222222222}, "21": {"effect": -0.007909124975914866, "value": 0.14285714285714285}, "22": {"effect": -0.008459206441151643, "value": 0.2}, "23": {"effect": -0.0036091584055994792, "value": 0.5}, "24": {"effect": -0.021490975133230752, "value": 0.0}, "25": {"effect": -0.0034575766430485605, "value": 0.5}, "26": {"effect": -0.12999328134698301, "value": 0.3333333333333333}, "27": {"effect": -0.07615646178714791, "value": 0.25}, "28": {"effect": -0.09005957035982701, "value": 0.25}, "29": {"effect": 0.20222030273189864, "value": 0.3333333333333333}, "30": {"effect": -0.047888680697128407, "value": 0.20754716981132074}, "31": {"effect": -0.06621627505441294, "value": 0.0}, "32": {"effect": -0.001589448615158074, "value": 0.125}, "33": {"effect": 0.007268530962323747, "value": 1.0}, "34": {"effect": 0.003362820705156161, "value": 0.0}, "35": {"effect": 0.04033101133923462, "value": 0.0}, "36": {"effect": 0.01465000900478492, "value": 1.0}, "37": {"effect": -0.001288819672498532, "value": 0.0}, "38": {"effect": 0.011433306893216078, "value": 0.0}, "39": {"effect": 0.004271419807116319, "value": 0.0}, "40": {"effect": -0.02079761393077308, "value": 0.0}, "41": {"effect": 0.011404592793900211, "value": 0.2857142857142857}, "42": {"effect": -0.01436602477760269, "value": 0.0}, "43": {"effect": 0.02546436016098334, "value": 0.0}, "44": {"effect": -0.032830397236472304, "value": 0.0}, "45": {"effect": -0.010332579232121046, "value": 0.0}, "46": {"effect": 0.03778277463409502, "value": 0.2857142857142857}, "47": {"effect": -0.3011274988352838, "value": 0.2857142857142857}, "48": { ...
#     document.getElementById('i45R1XBH1Q1BMNHZCZ42A')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='iQ3UX4YKSAQ1LLSBKIQC2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": 0.2448136836389827, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.019993602404394784, "value": 0.0}, "1": {"effect": 0.13726901287912563, "value": 0.0}, "2": {"effect": 0.060745275469119564, "value": 0.0}, "3": {"effect": 0.0023979490385298667, "value": 1.0}, "4": {"effect": 0.012165509652116867, "value": 0.0}, "5": {"effect": 0.060643960080355504, "value": 0.0}, "6": {"effect": 0.05719261070347769, "value": 0.0}, "7": {"effect": 0.17761910683608143, "value": 0.0}, "8": {"effect": -0.07892055986729847, "value": 0.2857142857142857}, "9": {"effect": 0.06154921876710655, "value": 0.0}, "10": {"effect": 0.03566819774410072, "value": 0.16216216216216214}, "11": {"effect": -0.005669527342029286, "value": 0.13793103448275862}, "12": {"effect": -0.006113784443442831, "value": 0.30000000000000004}, "13": {"effect": 0.07542514056100037, "value": 0.125}, "14": {"effect": 0.017860185746939695, "value": 0.125}, "15": {"effect": -0.002553608108804438, "value": 0.125}, "16": {"effect": -0.004540083198439052, "value": 0.0}, "17": {"effect": -0.0024833414295628003, "value": 0.1}, "18": {"effect": 0.021979350862627926, "value": 0.07142857142857142}, "19": {"effect": -9.396912796364979e-05, "value": 0.0}, "20": {"effect": -0.01408583428721066, "value": 0.2222222222222222}, "21": {"effect": -0.0034173714562769153, "value": 0.14285714285714285}, "22": {"effect": 0.012167072978533228, "value": 0.2}, "23": {"effect": 0.07184275347328695, "value": 0.5}, "24": {"effect": 0.09341953969276702, "value": 0.0}, "25": {"effect": 0.020736643369390816, "value": 0.5}, "26": {"effect": 0.021527190610637383, "value": 0.3333333333333333}, "27": {"effect": 0.0478904678139163, "value": 0.25}, "28": {"effect": 0.04259927704290076, "value": 0.25}, "29": {"effect": -0.03163363835509695, "value": 0.3333333333333333}, "30": {"effect": 0.04511525392424765, "value": 0.20754716981132074}, "31": {"effect": 0.05217017518239623, "value": 0.0}, "32": {"effect": 0.010431678624866679, "value": 0.125}, "33": {"effect": 0.030396268301922186, "value": 1.0}, "34": {"effect": 0.002384223480214982, "value": 0.0}, "35": {"effect": -0.059030491167607745, "value": 0.0}, "36": {"effect": 0.009118201087045063, "value": 1.0}, "37": {"effect": 0.0015649808177439998, "value": 0.0}, "38": {"effect": -0.0039901810740005095, "value": 0.0}, "39": {"effect": 0.005660511965091246, "value": 0.0}, "40": {"effect": 0.0076539033915197004, "value": 0.0}, "41": {"effect": 0.004384307292473989, "value": 0.2857142857142857}, "42": {"effect": 0.00951278740163441, "value": 0.0}, "43": {"effect": 0.00416817594059378, "value": 0.0}, "44": {"effect": 0.001236848851040913, "value": 0.0}, "45": {"effect": -0.0011685720312734557, "value": 0.0}, "46": {"effect": 0.02149537420348043, "value": 0.2857142857142857}, "47": {"effect": 0.004704346261678908, "value": 0.2857142857142857}, "48": {"effect" ...
#     document.getElementById('iQ3UX4YKSAQ1LLSBKIQC2')
#   );
# </script>

# %%
shap_values = explainer.shap_values(extreme_as_nonvul)
shap.summary_plot(shap_values, extreme_as_nonvul, class_names=['Extreme vulnerability', 'Moderate vulnerability', 'Vulnerable', 'Non-vulnerable'])
expected_value = explainer.expected_value
sample_and_explain(extreme_as_nonvul, 4, 42, shap_values, expected_value)
# Out:
# <h1>What influenced prediction for 1th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='iZ3EZ5UO0JZMDV6W51OEU'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": 0.5857820570959525, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.03352306136054979, "value": 0.0}, "1": {"effect": 0.03836877357609233, "value": 1.0}, "2": {"effect": 0.02601597287797269, "value": 1.0}, "3": {"effect": 0.02311793540452588, "value": 0.0}, "4": {"effect": 0.06843168288074471, "value": 1.0}, "5": {"effect": -0.03719060835223299, "value": 0.0}, "6": {"effect": -0.049992337266507016, "value": 0.0}, "7": {"effect": 0.16909950722602202, "value": 0.0}, "8": {"effect": 0.03489203548360863, "value": 0.2857142857142857}, "9": {"effect": -0.02172060584373339, "value": 0.0}, "10": {"effect": 0.01509858029707009, "value": 0.20270270270270271}, "11": {"effect": 0.04257888256523962, "value": 0.13793103448275862}, "12": {"effect": -0.0652572985788304, "value": 0.30000000000000004}, "13": {"effect": 0.004066961750488355, "value": 0.125}, "14": {"effect": -0.002183599857235023, "value": 0.125}, "15": {"effect": -0.0032967291143816487, "value": 0.125}, "16": {"effect": 0.0008331330820108968, "value": 0.0}, "17": {"effect": 0.004273383740995724, "value": 0.1}, "18": {"effect": 0.0025127187519019076, "value": 0.07142857142857142}, "19": {"effect": 0.025042255921151366, "value": 0.0}, "20": {"effect": 0.007659378269624329, "value": 0.2222222222222222}, "21": {"effect": -0.006470154574245476, "value": 0.14285714285714285}, "22": {"effect": -0.007189764910974468, "value": 0.2}, "23": {"effect": 0.0008866631720502858, "value": 1.0}, "24": {"effect": 0.025675953904773022, "value": 1.0}, "25": {"effect": 0.0024165382003083985, "value": 1.0}, "26": {"effect": 0.1450936116306232, "value": 1.0}, "27": {"effect": 0.02796985614751036, "value": 0.0}, "28": {"effect": -0.08188990826809978, "value": 0.25}, "29": {"effect": 0.27886800903733944, "value": 0.3333333333333333}, "30": {"effect": -0.04740541394291269, "value": 0.20754716981132074}, "31": {"effect": -0.022424084601924216, "value": 0.0}, "32": {"effect": -0.0012996782830540618, "value": 0.125}, "33": {"effect": 0.030193667950268226, "value": 1.0}, "34": {"effect": 0.003811635498591064, "value": 0.0}, "35": {"effect": 0.06682478416937912, "value": 0.0}, "36": {"effect": 0.044218997080889506, "value": 1.0}, "37": {"effect": -0.0026541880974353033, "value": 0.0}, "38": {"effect": 0.02073633827575727, "value": 0.0}, "39": {"effect": 0.0048812747756671665, "value": 0.0}, "40": {"effect": -0.0035762417080789904, "value": 0.0}, "41": {"effect": 0.01710496714645902, "value": 0.14285714285714285}, "42": {"effect": 0.021831114287241854, "value": 1.0}, "43": {"effect": -0.058026908882005575, "value": 1.0}, "44": {"effect": -0.010876830549491408, "value": 0.0}, "45": {"effect": -0.00800294925375425, "value": 0.0}, "46": {"effect": 0.09813164354267398, "value": 0.2857142857142857}, "47": {"effect": -0.1162473670046306, "value": 0.42857142857142855}, "48": {"effect": -0.03684333 ...
#     document.getElementById('iZ3EZ5UO0JZMDV6W51OEU')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='i3BM95NGJ7P8S1X7RKFC2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": -1.435608072229188, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.02218540205841178, "value": 0.0}, "1": {"effect": -0.074021311228948, "value": 1.0}, "2": {"effect": -0.027526448238699062, "value": 1.0}, "3": {"effect": -0.0014798287827255292, "value": 0.0}, "4": {"effect": -0.009548724905165541, "value": 1.0}, "5": {"effect": 0.045936744656775164, "value": 0.0}, "6": {"effect": 0.04017205439650709, "value": 0.0}, "7": {"effect": 0.14980352592931803, "value": 0.0}, "8": {"effect": -0.09457633048849758, "value": 0.2857142857142857}, "9": {"effect": -0.0040543557158058624, "value": 0.0}, "10": {"effect": -0.04421944751451705, "value": 0.20270270270270271}, "11": {"effect": -0.022132397804812885, "value": 0.13793103448275862}, "12": {"effect": -0.0022891170684361402, "value": 0.30000000000000004}, "13": {"effect": 0.0958480373030261, "value": 0.125}, "14": {"effect": -0.014333101169204984, "value": 0.125}, "15": {"effect": -0.00797072657773352, "value": 0.125}, "16": {"effect": -0.010688002513029454, "value": 0.0}, "17": {"effect": -0.005510365881609036, "value": 0.1}, "18": {"effect": 0.005276990522083184, "value": 0.07142857142857142}, "19": {"effect": 0.0007418697629312018, "value": 0.0}, "20": {"effect": -0.004535457223144063, "value": 0.2222222222222222}, "21": {"effect": -0.024433360039648005, "value": 0.14285714285714285}, "22": {"effect": -0.011383717396409582, "value": 0.2}, "23": {"effect": -0.029514422427100645, "value": 1.0}, "24": {"effect": -0.017979406435816647, "value": 1.0}, "25": {"effect": -0.02148843805533144, "value": 1.0}, "26": {"effect": -0.03867615083766553, "value": 1.0}, "27": {"effect": -0.01433804283378918, "value": 0.0}, "28": {"effect": 0.0279444254087963, "value": 0.25}, "29": {"effect": -0.0685574563980292, "value": 0.3333333333333333}, "30": {"effect": 0.07057453698373783, "value": 0.20754716981132074}, "31": {"effect": 0.05531700694392371, "value": 0.0}, "32": {"effect": 0.005323649361460183, "value": 0.125}, "33": {"effect": 0.013323710938774333, "value": 1.0}, "34": {"effect": -0.0001714016866078659, "value": 0.0}, "35": {"effect": -0.07350528706428579, "value": 0.0}, "36": {"effect": 0.011543044949135741, "value": 1.0}, "37": {"effect": 0.01633558374961861, "value": 0.0}, "38": {"effect": -0.002856884705652869, "value": 0.0}, "39": {"effect": -0.002330214186371715, "value": 0.0}, "40": {"effect": -0.007395680389430967, "value": 0.0}, "41": {"effect": 0.011999834595598915, "value": 0.14285714285714285}, "42": {"effect": 0.017147118167850788, "value": 1.0}, "43": {"effect": -0.0028354020603948977, "value": 1.0}, "44": {"effect": 0.0012368488510409107, "value": 0.0}, "45": {"effect": -0.004014456745170316, "value": 0.0}, "46": {"effect": 0.008311263179587832, "value": 0.2857142857142857}, "47": {"effect": -0.025991091112014485, "value": 0.42857142857142855}, "48": {"effect": ...
#     document.getElementById('i3BM95NGJ7P8S1X7RKFC2')
#   );
# </script>
# <h1>What influenced prediction for 2th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='i2WCHVCSDYOCW6Z9CJB2L'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": -0.30678244080168743, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.03954096981500419, "value": 0.0}, "1": {"effect": 0.038008321243230815, "value": 1.0}, "2": {"effect": -0.05244520454947515, "value": 0.0}, "3": {"effect": -0.010741682021548477, "value": 1.0}, "4": {"effect": -0.18681510171354676, "value": 0.0}, "5": {"effect": 0.050328105738005995, "value": 1.0}, "6": {"effect": -0.06011211585662596, "value": 0.031867742918243944}, "7": {"effect": 0.23027648291840036, "value": 0.0}, "8": {"effect": 0.005926084845005357, "value": 0.0}, "9": {"effect": -0.015772672579244678, "value": 0.0}, "10": {"effect": -0.2172056699818977, "value": 0.08108108108108109}, "11": {"effect": 0.02053239370598147, "value": 0.13793103448275862}, "12": {"effect": -0.05257306864290045, "value": 0.30000000000000004}, "13": {"effect": -0.006939354457924895, "value": 0.125}, "14": {"effect": -0.00045277886384551143, "value": 0.125}, "15": {"effect": -0.008189854643494648, "value": 0.125}, "16": {"effect": 0.0005485342048906778, "value": 0.0}, "17": {"effect": 0.008168308068471072, "value": 0.1}, "18": {"effect": 0.0015953376900815137, "value": 0.07142857142857142}, "19": {"effect": 0.01910929119918958, "value": 0.0}, "20": {"effect": 0.009175816314544194, "value": 0.2222222222222222}, "21": {"effect": -0.005167822279366737, "value": 0.14285714285714285}, "22": {"effect": -0.0043281760177397155, "value": 0.2}, "23": {"effect": -0.0030854613565249656, "value": 0.0}, "24": {"effect": -0.020059408626766456, "value": 0.0}, "25": {"effect": -0.008433315997048198, "value": 0.5}, "26": {"effect": -0.1274111241030493, "value": 0.16666666666666666}, "27": {"effect": 0.020445194213729197, "value": 0.25}, "28": {"effect": -0.06824042865621499, "value": 0.0}, "29": {"effect": 0.23558420581691758, "value": 0.3333333333333333}, "30": {"effect": -0.027752444529354617, "value": 0.20754716981132074}, "31": {"effect": 0.29901469204147163, "value": 0.0375}, "32": {"effect": -0.0013471369651187758, "value": 0.125}, "33": {"effect": -0.014556795001130551, "value": 1.0}, "34": {"effect": -0.010100592634694355, "value": 0.2}, "35": {"effect": 0.017513024639872577, "value": 0.0}, "36": {"effect": 3.693425186324099e-05, "value": 0.0}, "37": {"effect": 0.0004931662251514028, "value": 0.1}, "38": {"effect": 0.0010466351464296258, "value": 0.2}, "39": {"effect": 0.009450371833180071, "value": 0.0}, "40": {"effect": -0.015139331552553568, "value": 0.0}, "41": {"effect": 0.007505876737550361, "value": 0.14285714285714285}, "42": {"effect": 0.0423393137801409, "value": 1.0}, "43": {"effect": 0.028158424405350966, "value": 0.0}, "44": {"effect": -0.03305558364962221, "value": 0.0}, "45": {"effect": -0.0070480810325886855, "value": 0.0}, "46": {"effect": -0.11201507483115265, "value": 0.0}, "47": {"effect": -0.2936055824792951, "value": 0.2857142857142857}, "48":  ...
#     document.getElementById('i2WCHVCSDYOCW6Z9CJB2L')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='i9BJG694HAX3YO0CGF979'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": -1.0261146288313354, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.02312707954357585, "value": 0.0}, "1": {"effect": -0.07346861071811484, "value": 1.0}, "2": {"effect": 0.05328250263947345, "value": 0.0}, "3": {"effect": 0.001385446601366757, "value": 1.0}, "4": {"effect": 0.0210981627797716, "value": 0.0}, "5": {"effect": -0.03616258006486644, "value": 1.0}, "6": {"effect": -0.07673007714630346, "value": 0.031867742918243944}, "7": {"effect": -0.015630993145380835, "value": 0.0}, "8": {"effect": 0.00019810979377414404, "value": 0.0}, "9": {"effect": -0.007056476984355576, "value": 0.0}, "10": {"effect": 0.16413544738936295, "value": 0.08108108108108109}, "11": {"effect": -0.029545566875819364, "value": 0.13793103448275862}, "12": {"effect": -0.0007777623071216033, "value": 0.30000000000000004}, "13": {"effect": 0.10998407905689676, "value": 0.125}, "14": {"effect": 0.039978736588833996, "value": 0.125}, "15": {"effect": -0.0006507863610674979, "value": 0.125}, "16": {"effect": -0.014132329404001888, "value": 0.0}, "17": {"effect": -0.006995962805593228, "value": 0.1}, "18": {"effect": 0.00432417151468603, "value": 0.07142857142857142}, "19": {"effect": -0.00013534157050609625, "value": 0.0}, "20": {"effect": -0.0073982597227257385, "value": 0.2222222222222222}, "21": {"effect": 0.016298888090678178, "value": 0.14285714285714285}, "22": {"effect": -0.026063821990167813, "value": 0.2}, "23": {"effect": 0.037076753822556346, "value": 0.0}, "24": {"effect": 0.08512038097426483, "value": 0.0}, "25": {"effect": 0.014350478006724003, "value": 0.5}, "26": {"effect": 0.01929014566106587, "value": 0.16666666666666666}, "27": {"effect": 0.0510135701478954, "value": 0.25}, "28": {"effect": 0.013640504317960482, "value": 0.0}, "29": {"effect": 0.0213773844339783, "value": 0.3333333333333333}, "30": {"effect": 0.030971785946887737, "value": 0.20754716981132074}, "31": {"effect": -0.12147289044423838, "value": 0.0375}, "32": {"effect": 0.010326166948591764, "value": 0.125}, "33": {"effect": 0.01755749179854161, "value": 1.0}, "34": {"effect": 0.006420438797441806, "value": 0.2}, "35": {"effect": -0.046377554654360824, "value": 0.0}, "36": {"effect": -0.02046671507142737, "value": 0.0}, "37": {"effect": -0.01326597332381453, "value": 0.1}, "38": {"effect": 0.0061832605359372055, "value": 0.2}, "39": {"effect": -0.009721051207647075, "value": 0.0}, "40": {"effect": -0.037980918989606205, "value": 0.0}, "41": {"effect": -0.01142020864038968, "value": 0.14285714285714285}, "42": {"effect": -0.01812647036412305, "value": 1.0}, "43": {"effect": 0.010314879835724709, "value": 0.0}, "44": {"effect": 0.001236848851040913, "value": 0.0}, "45": {"effect": -0.004111226340109574, "value": 0.0}, "46": {"effect": 0.0077466028971138745, "value": 0.0}, "47": {"effect": -0.01839224964069225, "value": 0.2857142857142857}, "48": {"effect": ...
#     document.getElementById('i9BJG694HAX3YO0CGF979')
#   );
# </script>
# <h1>What influenced prediction for 6th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='iBBTGWIZW0LFMKSLI00GT'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": 0.17139725741657766, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.02615038219575781, "value": 1.0}, "1": {"effect": 0.033372974867442756, "value": 1.0}, "2": {"effect": 0.05725704488042993, "value": 1.0}, "3": {"effect": 0.02006195112952074, "value": 0.0}, "4": {"effect": 0.07522973973766667, "value": 1.0}, "5": {"effect": 0.009463748530529245, "value": 1.0}, "6": {"effect": -0.03446793600584011, "value": 0.0}, "7": {"effect": 0.19493458356331367, "value": 0.0}, "8": {"effect": -0.03853897649869188, "value": 0.0}, "9": {"effect": 0.00024550680037183694, "value": 0.42857142857142855}, "10": {"effect": -0.01379773560313997, "value": 0.2702702702702703}, "11": {"effect": 0.03065851961242083, "value": 0.13793103448275862}, "12": {"effect": -0.0071032672652725365, "value": 0.4}, "13": {"effect": -0.02965840338345829, "value": 0.0}, "14": {"effect": -0.005087139345522302, "value": 0.0}, "15": {"effect": 0.011510462471451115, "value": 0.25}, "16": {"effect": 0.00042792302935533595, "value": 0.0}, "17": {"effect": 0.002138260966089775, "value": 0.1}, "18": {"effect": 0.0014767635378914, "value": 0.07142857142857142}, "19": {"effect": 0.0452566789606586, "value": 0.0}, "20": {"effect": 0.008779316408429638, "value": 0.2222222222222222}, "21": {"effect": -0.01864362954058006, "value": 0.14285714285714285}, "22": {"effect": -0.009357971661292772, "value": 0.0}, "23": {"effect": 0.0008380184241321128, "value": 1.0}, "24": {"effect": 0.021438163894646162, "value": 1.0}, "25": {"effect": 0.005493210519259184, "value": 1.0}, "26": {"effect": 0.18914590835591877, "value": 1.0}, "27": {"effect": 0.012509123225637327, "value": 0.0}, "28": {"effect": -0.11872738346476366, "value": 0.25}, "29": {"effect": -0.40208630843465853, "value": 0.0}, "30": {"effect": 0.056148814236564364, "value": 0.2641509433962264}, "31": {"effect": -0.044256432542961785, "value": 0.0}, "32": {"effect": 0.013764238311081582, "value": 0.25}, "33": {"effect": -0.038006858411428666, "value": 0.0}, "34": {"effect": -0.00015886273171099232, "value": 0.1}, "35": {"effect": -0.020992371495483327, "value": 1.0}, "36": {"effect": 0.024417123892055685, "value": 0.0}, "37": {"effect": -0.01777969282685528, "value": 0.1}, "38": {"effect": 0.015970678041901668, "value": 0.0}, "39": {"effect": 0.0077494166742557375, "value": 0.0}, "40": {"effect": 0.0009385858673118552, "value": 0.0}, "41": {"effect": 0.0032130690148651584, "value": 0.0}, "42": {"effect": -0.005466168824838396, "value": 0.0}, "43": {"effect": -0.07318574110880559, "value": 1.0}, "44": {"effect": -0.01517205617619249, "value": 0.0}, "45": {"effect": -0.01016028829204665, "value": 0.0}, "46": {"effect": 0.15918393029308134, "value": 0.42857142857142855}, "47": {"effect": -0.13597787063031117, "value": 0.5238095238095237}, "48": {"effect": 0.027577214998274726, "value": 0.1724137931034483}, "49": { ...
#     document.getElementById('iBBTGWIZW0LFMKSLI00GT')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='iNYDB1T78E1D8F11LIME6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": -1.260563968804032, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.00572127365329674, "value": 1.0}, "1": {"effect": -0.0566815613469087, "value": 1.0}, "2": {"effect": -0.043933331079623265, "value": 1.0}, "3": {"effect": -0.018190743512864406, "value": 0.0}, "4": {"effect": -0.006587671200272526, "value": 1.0}, "5": {"effect": -0.011223258873505563, "value": 1.0}, "6": {"effect": 0.08422438697633762, "value": 0.0}, "7": {"effect": 0.12179226627108203, "value": 0.0}, "8": {"effect": 0.1567508782681779, "value": 0.0}, "9": {"effect": 0.047913968668478746, "value": 0.42857142857142855}, "10": {"effect": 0.008363327439332173, "value": 0.2702702702702703}, "11": {"effect": -0.03234650742049974, "value": 0.13793103448275862}, "12": {"effect": -0.014582545263323048, "value": 0.4}, "13": {"effect": 0.1038039785168602, "value": 0.0}, "14": {"effect": -0.006296192525948709, "value": 0.0}, "15": {"effect": -0.014819445500775057, "value": 0.25}, "16": {"effect": -0.01763589766653304, "value": 0.0}, "17": {"effect": -0.01706350672531111, "value": 0.1}, "18": {"effect": 0.004634673258462162, "value": 0.07142857142857142}, "19": {"effect": 0.0006749356678693293, "value": 0.0}, "20": {"effect": -0.004432556739547606, "value": 0.2222222222222222}, "21": {"effect": 0.024379705803204074, "value": 0.14285714285714285}, "22": {"effect": 0.02945484655799015, "value": 0.0}, "23": {"effect": -0.011336893936796122, "value": 1.0}, "24": {"effect": -0.009885265349875064, "value": 1.0}, "25": {"effect": -0.02745334427745066, "value": 1.0}, "26": {"effect": -0.0926102376273301, "value": 1.0}, "27": {"effect": -0.01765856371957652, "value": 0.0}, "28": {"effect": 0.01616626995108734, "value": 0.25}, "29": {"effect": 0.41419077974569674, "value": 0.0}, "30": {"effect": 0.043096525980930986, "value": 0.2641509433962264}, "31": {"effect": 0.05637949614589023, "value": 0.0}, "32": {"effect": 0.001582585041210085, "value": 0.25}, "33": {"effect": -0.17630604286411894, "value": 0.0}, "34": {"effect": -0.01783953960124244, "value": 0.1}, "35": {"effect": 0.07813720531343481, "value": 1.0}, "36": {"effect": -0.023517122732929826, "value": 0.0}, "37": {"effect": -0.0053411576132077155, "value": 0.1}, "38": {"effect": -0.0197018438801912, "value": 0.0}, "39": {"effect": -0.007623912256733025, "value": 0.0}, "40": {"effect": -0.021556920267133906, "value": 0.0}, "41": {"effect": 0.021657848349271373, "value": 0.0}, "42": {"effect": -0.019932167699364494, "value": 0.0}, "43": {"effect": 0.0004391395109913847, "value": 1.0}, "44": {"effect": 0.018983401417144358, "value": 0.0}, "45": {"effect": -0.0035018309373017033, "value": 0.0}, "46": {"effect": 0.0455070125601778, "value": 0.42857142857142855}, "47": {"effect": 0.02632449523931611, "value": 0.5238095238095237}, "48": {"effect": -0.0016405657809843827, "value": 0.1724137931034483}, "49": {"eff ...
#     document.getElementById('iNYDB1T78E1D8F11LIME6')
#   );
# </script>
# <h1>What influenced prediction for 3th sample</h1>
# <h2>Prediction of class 4 (Non-vulnerable) probability
# <div id='iUKHNQQ7P7KLPR078QHOX'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": 0.11574749243109543, "outValue": 1.8652203202552433, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": 0.021424055828263823, "value": 1.0}, "1": {"effect": 0.01845103497538583, "value": 1.0}, "2": {"effect": 0.031821972995263834, "value": 1.0}, "3": {"effect": -0.023238496426885157, "value": 1.0}, "4": {"effect": 0.04148659560205247, "value": 1.0}, "5": {"effect": -0.06444395124425147, "value": 0.0}, "6": {"effect": -0.024274732524193744, "value": 0.0}, "7": {"effect": 0.16486926457582346, "value": 0.0}, "8": {"effect": 0.045118286150378564, "value": 0.7142857142857142}, "9": {"effect": -0.004369368314075232, "value": 0.0}, "10": {"effect": 0.1453633548388804, "value": 0.40540540540540543}, "11": {"effect": 0.06715057101620783, "value": 0.13793103448275862}, "12": {"effect": -0.02309309741548843, "value": 0.20000000000000004}, "13": {"effect": 0.015454570741368872, "value": 0.125}, "14": {"effect": 0.0011362895189000318, "value": 0.125}, "15": {"effect": -0.0021685590702024806, "value": 0.125}, "16": {"effect": 0.00043009856973304244, "value": 0.0}, "17": {"effect": 0.003686876175893865, "value": 0.1}, "18": {"effect": 0.0013646795894323778, "value": 0.07142857142857142}, "19": {"effect": 0.0374489661296748, "value": 0.0}, "20": {"effect": 0.0028142777733080188, "value": 0.2222222222222222}, "21": {"effect": -0.003261744805967255, "value": 0.14285714285714285}, "22": {"effect": -0.02842131821522353, "value": 0.2}, "23": {"effect": 0.005092028337922727, "value": 1.0}, "24": {"effect": -0.016093866418053656, "value": 0.0}, "25": {"effect": 0.0011994403383067676, "value": 1.0}, "26": {"effect": -0.16637860403440805, "value": 0.6666666666666666}, "27": {"effect": 0.016932848291051832, "value": 0.0}, "28": {"effect": -0.0814941709552283, "value": 0.25}, "29": {"effect": 0.19080422715560263, "value": 0.3333333333333333}, "30": {"effect": 0.09150730674535837, "value": 0.1509433962264151}, "31": {"effect": -0.020424462017364354, "value": 0.0}, "32": {"effect": -0.0002459487895212615, "value": 0.125}, "33": {"effect": 0.010463022667948112, "value": 1.0}, "34": {"effect": 0.01177469007700806, "value": 0.0}, "35": {"effect": 0.083666485632669, "value": 0.0}, "36": {"effect": 0.02446558017899595, "value": 1.0}, "37": {"effect": 0.006056761540144508, "value": 0.0}, "38": {"effect": 0.009179609360186199, "value": 0.0}, "39": {"effect": 0.007289219986113498, "value": 0.0}, "40": {"effect": -0.00042708242351354115, "value": 0.0}, "41": {"effect": -0.01151095758694313, "value": 0.0}, "42": {"effect": -0.011164537609488922, "value": 0.0}, "43": {"effect": 0.04754642001448769, "value": 0.0}, "44": {"effect": 0.04970367294683016, "value": 1.0}, "45": {"effect": 0.10073720453990226, "value": 0.4}, "46": {"effect": 0.3361275498636322, "value": 0.7142857142857142}, "47": {"effect": 0.39311130501598873, "value": 0.7142857142857142}, "48": {"effect": 0.0527438036918862 ...
#     document.getElementById('iUKHNQQ7P7KLPR078QHOX')
#   );
# </script>
# <h2>Prediction of class 1 (Extreme vulnerability) probability
# <div id='iHCNTA4BQGIPYFT7U7WIZ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["output value"], "baseValue": -1.526778097868476, "outValue": -1.8402408590712311, "link": "identity", "featureNames": ["paredblolad", "pisomoscer", "cielorazo", "energcocinar3", "eviv3", "lugar1", "v2a1", "dependency", "edjefe", "edjefa", "meaneduc", "overcrowding", "rooms", "r4h2", "r4h3", "r4m3", "r4t1", "r4t2", "tamviv", "hogar_nin", "hogar_adul", "bedrooms", "qmobilephone", "walls", "roof", "floor", "walls+roof+floor", "warning", "bonus", "phones-per-capita", "rooms-per-capita", "rent-per-capita", "female-sum", "female-std", "estadocivil7-sum", "estadocivil7-std", "parentesco2-std", "parentesco3-sum", "instlevel1-sum", "instlevel2-sum", "instlevel2-std", "instlevel3-sum", "instlevel3-std", "instlevel4-std", "instlevel8-max", "instlevel8-sum", "escolari-min", "escolari-max", "escolari-sum", "escolari-std", "escolari-range_", "age-min", "age-max", "age-sum", "age-std", "age-range_", "inst-max", "inst-std", "inst-range_", "escolari/age-min", "escolari/age-max", "escolari/age-sum", "escolari/age-std", "escolari/age-range_", "inst/age-max", "inst/age-std", "inst/age-range_", "tech-sum"], "features": {"0": {"effect": -0.007663852281261958, "value": 1.0}, "1": {"effect": -0.06518430431796049, "value": 1.0}, "2": {"effect": -0.031151289265165603, "value": 1.0}, "3": {"effect": 0.004323688076259298, "value": 1.0}, "4": {"effect": -0.01592560199352979, "value": 1.0}, "5": {"effect": 0.07221344580131393, "value": 0.0}, "6": {"effect": 0.030978998289693745, "value": 0.0}, "7": {"effect": 0.05362231010918916, "value": 0.0}, "8": {"effect": -0.13626247593816213, "value": 0.7142857142857142}, "9": {"effect": -0.003983639430403305, "value": 0.0}, "10": {"effect": 0.019468264570357212, "value": 0.40540540540540543}, "11": {"effect": -0.019666236327506817, "value": 0.13793103448275862}, "12": {"effect": -0.04740823064220308, "value": 0.20000000000000004}, "13": {"effect": -0.01978914155598941, "value": 0.125}, "14": {"effect": -0.0015735551635734275, "value": 0.125}, "15": {"effect": -0.008314362668015583, "value": 0.125}, "16": {"effect": -0.00641678546604452, "value": 0.0}, "17": {"effect": -0.0042821438533939575, "value": 0.1}, "18": {"effect": 0.010336230210468932, "value": 0.07142857142857142}, "19": {"effect": 0.0006491236045085222, "value": 0.0}, "20": {"effect": -0.005470557079872196, "value": 0.2222222222222222}, "21": {"effect": -0.004099316529743607, "value": 0.14285714285714285}, "22": {"effect": 0.011067286936507765, "value": 0.2}, "23": {"effect": -0.03709351567641044, "value": 1.0}, "24": {"effect": 0.1229362413743124, "value": 0.0}, "25": {"effect": -0.015230375583574486, "value": 1.0}, "26": {"effect": 0.029180657696818754, "value": 0.6666666666666666}, "27": {"effect": -0.01676536178636661, "value": 0.0}, "28": {"effect": 0.03951788104097201, "value": 0.25}, "29": {"effect": -0.08183495839078994, "value": 0.3333333333333333}, "30": {"effect": -0.030573625063297725, "value": 0.1509433962264151}, "31": {"effect": 0.013383475722194716, "value": 0.0}, "32": {"effect": 0.008471292987518291, "value": 0.125}, "33": {"effect": 0.027612483194336856, "value": 1.0}, "34": {"effect": 0.0021531355788936956, "value": 0.0}, "35": {"effect": -0.04580572503580557, "value": 0.0}, "36": {"effect": 0.008859216424193557, "value": 1.0}, "37": {"effect": 0.0010348393583393483, "value": 0.0}, "38": {"effect": -0.004183770672363381, "value": 0.0}, "39": {"effect": -0.001256318326445884, "value": 0.0}, "40": {"effect": -0.019593761476271353, "value": 0.0}, "41": {"effect": -0.005202082539718239, "value": 0.0}, "42": {"effect": 0.00013814871872712788, "value": 0.0}, "43": {"effect": -0.0031731586666629884, "value": 0.0}, "44": {"effect": -0.01853141566911711, "value": 1.0}, "45": {"effect": 0.004379840943687537, "value": 0.4}, "46": {"effect": -0.03419498263391576, "value": 0.7142857142857142}, "47": {"effect": -0.004110015422415408, "value": 0.7142857142857142}, "48": {"effec ...
#     document.getElementById('iHCNTA4BQGIPYFT7U7WIZ')
#   );
# </script>
